# %% [markdown]
# # 住宅価格

# %% [markdown]
# ## 【問題1】データセットの取得

# %%
import numpy as np #行列
import pandas as pd #データ分析
import matplotlib.pyplot as plt
import seaborn as sns #matplotlibを使いやすくしたもの
# %matplotlib inline

import pandas_profiling as pdp #pandas report

# pdp.ProfileReport(df)  #分析してくれる

import cv2

# %%
df=pd.read_csv('train.csv')

# %%
len(df)
# Out:
# 1460

# %%
y.mean()
# Out:
# 180921.19589041095

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# # 【問題1】練習のために特徴量の選択

# %%
X = df.loc[:, ['GrLivArea', 'YearBuilt']] # GrLivArea: Above grade (ground) living area square feet

# %%
X.head()
# Out:
#    GrLivArea  YearBuilt
# 0       1710       2003
# 1       1262       1976
# 2       1786       2001
# 3       1717       1915
# 4       2198       2000

# %%
y=df.loc[:, ['SalePrice']]

# %%
y.head()
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
len(X)
# Out:
# 1460

# %%
len(y)
# Out:
# 1460

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.YearBuilt.head()
# Out:
# 0    2003
# 1    1976
# 2    2001
# 3    1915
# 4    2000
# Name: YearBuilt, dtype: int64

# %%
import numpy as np #適当な配列作るためにNumpy使う
import matplotlib.pyplot as plt

#seabornはimportしておくだけでもmatplotlibのグラフがきれいになる
#デフォルトでスタイルはdarkgridなのでsns.set_style()は書かなくても良い
import seaborn as sns
sns.set_style("darkgrid")

#3次元プロットするためのモジュール
from mpl_toolkits.mplot3d import Axes3D

#グラフの枠を作っていく
fig = plt.figure()
ax = Axes3D(fig)

#軸にラベルを付けたいときは書く
ax.set_xlabel("GrLivArea")
ax.set_ylabel("YearBuilt")
ax.set_zlabel("SalePrice")

#.plotで描画
#linestyle='None'にしないと初期値では線が引かれるが、3次元の散布図だと大抵ジャマになる
#markerは無難に丸
ax.plot(X.GrLivArea, X.YearBuilt, y.SalePrice ,marker="o",linestyle='None')

#最後に.show()を書いてグラフ表示
plt.show()

# %%
sns.violinplot(data=X)

# %%
sns.violinplot(data=y)

# %%
sns.violinplot(data=X['GrLivArea'])

# %%
sns.violinplot(data=X['YearBuilt'])

# %%
sns.pairplot(X)

# %%
sns.scatterplot(X.YearBuilt, y.SalePrice)

# %%
sns.scatterplot(X.GrLivArea, y.SalePrice)

# %% [markdown]
# 面積が広いほど、新しいほど、価格は高い
# 面積のほうが強く効いていそう

# %%
X = X.values
y = y.values

# %%
from sklearn.model_selection import train_test_split

# %%
test_size=0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)

# %%
len(X_train)
# Out:
# 1095

# %%
from sklearn.linear_model import LinearRegression

# %%
LinR=LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_transform = scaler.transform(X_train)
X_test_transform = scaler.transform(X_test)

# %%
sns.violinplot(data=X_train_transform[0])

# %%
sns.violinplot(data=X_train_transform[1])

# %%
LinR.fit(X_train_transform, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LinR.score(X_train_transform, y_train)
# Out:
# 0.6287982953795751

# %%
LinR.score(X_test_transform, y_test)
# Out:
# 0.7189451126659059

# %%
from sklearn.metrics import mean_squared_error

# %%
y_test_pred = LinR.predict(X_test_transform)
y_train_pred = LinR.predict(X_train_transform)

# %%
mean_squared_error(y_train, y_train_pred)
# Out:
# 2287896091.672831

# %%
mean_squared_error(y_train, y_train_pred) ** 0.5
# Out:
# 47831.9568037189

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 1886785549.9599533

# %%
mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 43437.14481823078

# %%
y.mean()
# Out:
# 180921.19589041095

# %%
df=X_test_transform[:, 0]

# %%
x0=X_test_transform[:, 0] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 1] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
y_test.shape
# Out:
# (365, 1)

# %%
len(y_test)
# Out:
# 365

# %%
from sklearn.svm import SVR

# %%
svr=SVR()

# %%
svr.fit(X_train_transform, y_train)
# Out:
# /Users/ikono/Desktop/kikagaku_data/myvenv/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svr.score(X_train_transform, y_train)
# Out:
# -0.046507074124592096

# %%
svr.score(X_test_transform, y_test)
# Out:
# -0.01827550699394398

# %%
y_test_pred = svr.predict(X_test_transform)
y_train_pred = svr.predict(X_train_transform)

# %%
mean_squared_error(y_train, y_train_pred) ** 0.5
# Out:
# 80312.7046115298

# %%
mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 82679.59654166763

# %%
x0=X_test_transform[:, 0] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 1] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train_transform, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
dtr.score(X_train_transform, y_train)
# Out:
# 0.9990526711713179

# %%
dtr.score(X_test_transform, y_test)
# Out:
# 0.6066492271841646

# %%
y_test_pred = dtr.predict(X_test_transform)
y_train_pred = dtr.predict(X_train_transform)

# %%
mean_squared_error(y_train, y_train_pred) ** 0.5
# Out:
# 2416.370606176274

# %%
mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 51387.28867107787

# %%
x0=X_test_transform[:, 0] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 1] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train_transform, y_train)
# Out:
# /Users/ikono/Desktop/kikagaku_data/myvenv/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/ikono/Desktop/kikagaku_data/myvenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
# ...

# %%
rfr.score(X_train_transform, y_train)
# Out:
# 0.9480939195892428

# %%
rfr.score(X_test_transform, y_test)
# Out:
# 0.7378991246869516

# %%
y_test_pred = rfr.predict(X_test_transform)
y_train_pred = rfr.predict(X_train_transform)

# %%
mean_squared_error(y_train, y_train_pred) ** 0.5
# Out:
# 17886.373066839973

# %%
mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 41946.906262816214

# %%
x0=X_test_transform[:, 0] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 1] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %% [markdown]
# ## 考察
# 線形回帰　43437
# SVM　　　　82679
# 決定木　　51387
# ランダムフォレスト　　41946
#
# RMSEが少ないランダムフォレストが精度が高い

# %% [markdown]
# # 問題4】（アドバンス課題）他の特徴量も使用しての学習

# %%
X = df.drop('SalePrice', axis=1).select_dtypes(include='number')
#X = X.fillna(X.mean)

# %%
X.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
X = X.drop(['LotFrontage', 'GarageYrBlt', 'MasVnrArea'], axis=1)

# %%
X.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
y=df['SalePrice']

# %%
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
X = X.values
y = y.values

# %%
test_size=0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)

# %%
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_transform = scaler.transform(X_train)
X_test_transform = scaler.transform(X_test)

# %%
LinR.fit(X_train_transform, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LinR.score(X_train_transform, y_train)
# Out:
# 0.7963723720283304

# %%
LinR.score(X_test_transform, y_test)
# Out:
# 0.8195567149651302

# %%
y_test_pred = LinR.predict(X_test_transform)
y_train_pred = LinR.predict(X_train_transform)

mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 34804.55315650295

# %%
x0=X_test_transform[:, 14] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 6] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
svr.fit(X_train_transform, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svr.score(X_train_transform, y_train)
# Out:
# -0.04807604065437787

# %%
svr.score(X_test_transform, y_test)
# Out:
# -0.019769468312619276

# %%
y_test_pred = svr.predict(X_test_transform)
y_train_pred = svr.predict(X_train_transform)

mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 82740.22593216461

# %%
x0=X_test_transform[:, 14] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 6] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
dtr.fit(X_train_transform, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_test_pred = dtr.predict(X_test_transform)
y_train_pred = dtr.predict(X_train_transform)

mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 44402.42041674928

# %%
x0=X_test_transform[:, 14] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 6] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
rfr.fit(X_train_transform, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_test_pred = rfr.predict(X_test_transform)
y_train_pred = rfr.predict(X_train_transform)

mean_squared_error(y_test, y_test_pred) ** 0.5
# Out:
# 26913.328395321867

# %%
x0=X_test_transform[:, 14] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %%
x0=X_test_transform[:, 6] #.reshape(365, 1)

sns.scatterplot(x0, y_test.reshape(365,), label='true', color = 'red')
sns.scatterplot(x0, y_test_pred.reshape(365,), label='predict', color = 'blue')

# %% [markdown]
# ## 考察
#
# ＜２変数＞
# 線形回帰　43437
# SVM　　　　82679
# 決定木　　51387
# ランダムフォレスト　　41946
#
# ＜今回＞
# 線形回帰　34804
# SVM　　　　82740
# 決定木　　44402
# ランダムフォレスト　　26913
#
# SVM以外は改善。特にランダムフォレストは著明に改善。
# 平均 180M ＄のところの誤差が26M ＄程度
